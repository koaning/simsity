# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

from sklearn.pipeline import make_pipeline, make_union
from sklearn.feature_extraction.text import CountVectorizer

from simsity.indexer import PyNNDescentIndexer
from simsity.service import Service
from simsity.preprocessing import ColumnLister

from whatlies.language import BytePairLanguage

def predict_value(df_valid):
    results = [] 
    for d in tqdm(df_valid.to_dict(orient='records'), desc="calculating stats"):
        results_df = service.query(text=d['text'], out="dataframe", n_neighbors=40)
        for k in range(1, 40):
            df_at_k = results_df.head(k)
            precision = np.mean(df_at_k['label'] == d['label'])
            recall = np.sum(df_at_k['label'] == d['label'])/30
            results.append({'precision': precision, 'recall': recall, 'k': k, 'text': d['text']})
    return results

# %%
df = pd.read_csv("../tests/data/clinc-data.csv")
df_train, df_valid = df.loc[lambda d: d['split'] == 'train'], df.loc[lambda d: d['split'] == 'valid']

# %%
# %%time 

encoder = make_pipeline(
    ColumnLister('text'), 
    make_union(
        CountVectorizer(),
    )
)
indexer = PyNNDescentIndexer(metric="cosine", n_jobs=10)
service = Service(encoder=encoder, indexer=indexer)
service.train_from_dataf(df_train)

results_df_orig = predict_value(df_valid)
# Out:
# calculating stats: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 5500/5500 [01:45<00:00, 51.96it/s]
# CPU times: user 2min 42s, sys: 1.94 s, total: 2min 44s
# Wall time: 2min 16s

# %%
# %%time 

encoder = make_pipeline(
    ColumnLister('text'), 
    make_union(
        CountVectorizer(),
        CountVectorizer(analyzer="char", ngram_range=(2, 3)),
        BytePairLanguage("en", vs=1_000),
        BytePairLanguage("en", vs=100_000),
    )
)
indexer = PyNNDescentIndexer(metric="cosine", n_jobs=10)
service = Service(encoder=encoder, indexer=indexer)
service.train_from_dataf(df_train)

results_df_new = predict_value(df_valid)
# Out:
# calculating stats: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 5500/5500 [02:25<00:00, 37.93it/s]
# CPU times: user 6min 36s, sys: 4min 49s, total: 11min 25s
# Wall time: 3min 36s

# %%
plot_df = (pd.concat([
                pd.DataFrame(results_df_orig).assign(setting="orig"), 
                pd.DataFrame(results_df_new).assign(setting="new")
            ])
           .groupby(["k", "setting"]).mean()
           .reset_index()
           .melt(id_vars=["k", "setting"]))

# %%
print(plot_df.head())
# Out:
#    k setting   variable     value
# 0  1     new  precision  0.656000
# 1  1    orig  precision  0.616727
# 2  2     new  precision  0.636182
# 3  2    orig  precision  0.590000
# 4  3     new  precision  0.620606

# %%
import altair as alt

p1 = (alt.Chart(plot_df.loc[lambda d: d['setting'] == 'orig'])
  .mark_line(strokeDash=[5,3])
  .encode(x='k', y='value', color='variable')
  .properties(width=600, height=250)
  .interactive())

p2 = (alt.Chart(plot_df.loc[lambda d: d['setting'] == 'new'])
  .mark_line()
  .encode(x='k', y='value', color='variable')
  .properties(width=600, height=250)
  .interactive())

(p1 + p2).properties(title="old (dashed) vs. new (straight) results at-k")
# Out:
# alt.LayerChart(...)

# %%
# If you want to save/host the altair chart.
print((p1 + p2).to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",
#   "config": {
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400
#     }
#   },
#   "datasets": {
#     "data-b4b51f601ddf0705ff19eae62b3a4007": [
#       {
#         "k": 1,
#         "setting": "new",
#         "value": 0.656,
#         "variable": "precision"
#       },
#       {
#         "k": 2,
#         "setting": "new",
#         "value": 0.6361818181818182,
#         "variable": "precision"
#       },
#       {
#         "k": 3,
#         "setting": "new",
#         "value": 0.6206060606060606,
#         "variable": "precision"
#       },
#       {
#         "k": 4,
#         "setting": "new",
#         "value": 0.6077272727272728,
#         "variable": "precision"
#       },
#       {
#         "k": 5,
#         "setting": "new",
#         "value": 0.5962545454545455,
#         "variable": "precision"
#       },
#       {
#         "k": 6,
#         "setting": "new",
#         "value": 0.5866666666666667,
#         "variable": "precision"
#       },
#       {
#         "k": 7,
#         "setting": "new",
#         "value": 0.578,
#         "variable": "precision"
#       },
#       {
#         "k": 8,
#         "setting": "new",
#         "value": 0.5687045454545454,
#         "variable": "precision"
#       },
#       {
#         "k": 9,
#         "setting": "new",
#         "value": 0.560949494949495,
#         "variable": "precision"
#       },
#       {
#         "k": 10,
#         "setting": "new",
#         "value": 0.5538727272727273,
#         "variable": "precision"
#       },
#       {
#         "k": 11,
#         "setting": "new",
#         "value": 0.5466776859504132,
#         "variable": "precision"
#       },
#       {
#         "k": 12,
#         "setting": "new",
#         "value": 0.5406818181818182,
#         "variable": "precision"
#       },
#       {
#         "k": 13,
#         "setting": "new",
#         "value": 0.5342377622377622,
#         "variable": "precision"
#       },
#       {
#         "k": 14,
#         "setting": "new",
#         "value": 0.5281818181818182,
#         "variable": "precision"
#       },
#       {
#         "k": 15,
#         "setting": "new",
#         "value": 0.522230303030303,
#         "variable": "precision"
#       },
#       {
#         "k": 16,
#         "setting": "new",
#         "value": 0.5163068181818182,
#         "variable": "precision"
#       },
#       {
#         "k": 17,
#         "setting": "new",
#         "value": 0.510855614973262,
#         "variable": "precision"
#       },
#       {
#         "k": 18,
#         "setting": "new",
#         "value": 0.5052929292929293,
#         "variable": "precision"
#       },
#       {
#         "k": 19,
#         "setting": "new",
#         "value": 0.4992918660287081,
#         "variable": "precision"
#       },
#       {
#         "k": 20,
#         "setting": "new",
#         "value": 0.49415454545454546,
#         "variable": "precision"
#       },
#       {
#         "k": 21,
#         "setting": "new",
#         "value": 0.48908225108225106,
#         "variable": "precision"
#       },
#       {
#         "k": 22,
#         "setting": "new",
#         "value": 0.48433884297520663,
#         "variable": "precision"
#       },
#       {
#         "k": 23,
#         "setting": "new",
#         "value": 0.47983399209486166,
#         "variable": "precision"
#       },
#       {
#         "k": 24,
#         "setting": "new",
#         "value": 0.475219696969697,
#         "variable": "precision"
#       },
#       {
#         "k": 25,
#         "setting": "new",
#         "value": 0.47056,
#         "variable": "precision"
#       },
#       {
#         "k": 26,
#         "setting": "new",
#         "value": 0.46606993006993,
#         "variable": "precision"
#       },
#       {
#         "k": 27,
#         "setting": "new",
#         "value": 0.46198653198653195,
#         "variable": "precision"
#       },
#       {
#         "k": 28,
#         "setting": "new",
#         "value": 0.4578961038961039,
#         "variable": "precision"
#       },
#       {
#         "k": 29,
#         "setting": "new",
#         "value": 0.45403761755485894,
#         "variable": "precision"
#       },
#       {
#         "k": 30,
#         "setting": "new",
#         "value": 0.45039393939393935,
#         "variable": "precision"
#       },
#       {
#         "k": 31,
#         "setting": "new",
#         "value": 0.4465865102639296,
#         "variable": "precision"
#       },
#       {
#         "k": 32,
#         "setting": "new",
#         "value": 0.4431022727272727,
#         "variable": "precision"
#       },
#       {
#         "k": 33,
#         "setting": "new",
#         "value": 0.43948209366391183,
#         "variable": "precision"
#       },
#       {
#         "k": 34,
#         "setting": "new",
#         "value": 0.43580213903743314,
#         "variable": "precision"
#       },
#       {
#         "k": 35,
#         "setting": "new",
#         "value": 0.432212987012987,
#         "variable": "precision"
#       },
#       {
#         "k": 36,
#         "setting": "new",
#         "value": 0.42868181818181816,
#         "variable": "precision"
#       },
#       {
#         "k": 37,
#         "setting": "new",
#         "value": 0.42532678132678137,
#         "variable": "precision"
#       },
#       {
#         "k": 38,
#         "setting": "new",
#         "value": 0.42203349282296654,
#         "variable": "precision"
#       },
#       {
#         "k": 39,
#         "setting": "new",
#         "value": 0.41885314685314684,
#         "variable": "precision"
#       },
#       {
#         "k": 1,
#         "setting": "new",
#         "value": 0.021866666666666666,
#         "variable": "recall"
#       },
#       {
#         "k": 2,
#         "setting": "new",
#         "value": 0.04241212121212121,
#         "variable": "recall"
#       },
#       {
#         "k": 3,
#         "setting": "new",
#         "value": 0.062060606060606066,
#         "variable": "recall"
#       },
#       {
#         "k": 4,
#         "setting": "new",
#         "value": 0.08103030303030304,
#         "variable": "recall"
#       },
#       {
#         "k": 5,
#         "setting": "new",
#         "value": 0.09937575757575756,
#         "variable": "recall"
#       },
#       {
#         "k": 6,
#         "setting": "new",
#         "value": 0.11733333333333335,
#         "variable": "recall"
#       },
#       {
#         "k": 7,
#         "setting": "new",
#         "value": 0.13486666666666666,
#         "variable": "recall"
#       },
#       {
#         "k": 8,
#         "setting": "new",
#         "value": 0.15165454545454546,
#         "variable": "recall"
#       },
#       {
#         "k": 9,
#         "setting": "new",
#         "value": 0.16828484848484848,
#         "variable": "recall"
#       },
#       {
#         "k": 10,
#         "setting": "new",
#         "value": 0.1846242424242424,
#         "variable": "recall"
#       },
#       {
#         "k": 11,
#         "setting": "new",
#         "value": 0.20044848484848485,
#         "variable": "recall"
#       },
#       {
#         "k": 12,
#         "setting": "new",
#         "value": 0.21627272727272728,
#         "variable": "recall"
#       },
#       {
#         "k": 13,
#         "setting": "new",
#         "value": 0.2315030303030303,
#         "variable": "recall"
#       },
#       {
#         "k": 14,
#         "setting": "new",
#         "value": 0.2464848484848485,
#         "variable": "recall"
#       },
#       {
#         "k": 15,
#         "setting": "new",
#         "value": 0.2611151515151515,
#         "variable": "recall"
#       },
#       {
#         "k": 16,
#         "setting": "new",
#         "value": 0.27536363636363637,
#         "variable": "recall"
#       },
#       {
#         "k": 17,
#         "setting": "new",
#         "value": 0.2894848484848485,
#         "variable": "recall"
#       },
#       {
#         "k": 18,
#         "setting": "new",
#         "value": 0.3031757575757576,
#         "variable": "recall"
#       },
#       {
#         "k": 19,
#         "setting": "new",
#         "value": 0.31621818181818184,
#         "variable": "recall"
#       },
#       {
#         "k": 20,
#         "setting": "new",
#         "value": 0.32943636363636364,
#         "variable": "recall"
#       },
#       {
#         "k": 21,
#         "setting": "new",
#         "value": 0.34235757575757575,
#         "variable": "recall"
#       },
#       {
#         "k": 22,
#         "setting": "new",
#         "value": 0.35518181818181815,
#         "variable": "recall"
#       },
#       {
#         "k": 23,
#         "setting": "new",
#         "value": 0.36787272727272724,
#         "variable": "recall"
#       },
#       {
#         "k": 24,
#         "setting": "new",
#         "value": 0.38017575757575756,
#         "variable": "recall"
#       },
#       {
#         "k": 25,
#         "setting": "new",
#         "value": 0.3921333333333333,
#         "variable": "recall"
#       },
#       {
#         "k": 26,
#         "setting": "new",
#         "value": 0.4039272727272727,
#         "variable": "recall"
#       },
#       {
#         "k": 27,
#         "setting": "new",
#         "value": 0.4157878787878788,
#         "variable": "recall"
#       },
#       {
#         "k": 28,
#         "setting": "new",
#         "value": 0.42736969696969695,
#         "variable": "recall"
#       },
#       {
#         "k": 29,
#         "setting": "new",
#         "value": 0.4389030303030303,
#         "variable": "recall"
#       },
#       {
#         "k": 30,
#         "setting": "new",
#         "value": 0.45039393939393935,
#         "variable": "recall"
#       },
#       {
#         "k": 31,
#         "setting": "new",
#         "value": 0.46147272727272726,
#         "variable": "recall"
#       },
#       {
#         "k": 32,
#         "setting": "new",
#         "value": 0.47264242424242425,
#         "variable": "recall"
#       },
#       {
#         "k": 33,
#         "setting": "new",
#         "value": 0.48343030303030304,
#         "variable": "recall"
#       },
#       {
#         "k": 34,
#         "setting": "new",
#         "value": 0.4939090909090909,
#         "variable": "recall"
#       },
#       {
#         "k": 35,
#         "setting": "new",
#         "value": 0.5042484848484848,
#         "variable": "recall"
#       },
#       {
#         "k": 36,
#         "setting": "new",
#         "value": 0.5144181818181819,
#         "variable": "recall"
#       },
#       {
#         "k": 37,
#         "setting": "new",
#         "value": 0.5245696969696969,
#         "variable": "recall"
#       },
#       {
#         "k": 38,
#         "setting": "new",
#         "value": 0.5345757575757576,
#         "variable": "recall"
#       },
#       {
#         "k": 39,
#         "setting": "new",
#         "value": 0.5445090909090909,
#         "variable": "recall"
#       }
#     ],
#     "data-dadf82f9e97c86c9e017e3d22ff7dcf6": [
#       {
#         "k": 1,
#         "setting": "orig",
#         "value": 0.6167272727272727,
#         "variable": "precision"
#       },
#       {
#         "k": 2,
#         "setting": "orig",
#         "value": 0.59,
#         "variable": "precision"
#       },
#       {
#         "k": 3,
#         "setting": "orig",
#         "value": 0.5713939393939393,
#         "variable": "precision"
#       },
#       {
#         "k": 4,
#         "setting": "orig",
#         "value": 0.5561818181818182,
#         "variable": "precision"
#       },
#       {
#         "k": 5,
#         "setting": "orig",
#         "value": 0.5410181818181818,
#         "variable": "precision"
#       },
#       {
#         "k": 6,
#         "setting": "orig",
#         "value": 0.5287272727272727,
#         "variable": "precision"
#       },
#       {
#         "k": 7,
#         "setting": "orig",
#         "value": 0.517974025974026,
#         "variable": "precision"
#       },
#       {
#         "k": 8,
#         "setting": "orig",
#         "value": 0.5073181818181818,
#         "variable": "precision"
#       },
#       {
#         "k": 9,
#         "setting": "orig",
#         "value": 0.4973939393939394,
#         "variable": "precision"
#       },
#       {
#         "k": 10,
#         "setting": "orig",
#         "value": 0.4892363636363637,
#         "variable": "precision"
#       },
#       {
#         "k": 11,
#         "setting": "orig",
#         "value": 0.4808925619834711,
#         "variable": "precision"
#       },
#       {
#         "k": 12,
#         "setting": "orig",
#         "value": 0.47239393939393937,
#         "variable": "precision"
#       },
#       {
#         "k": 13,
#         "setting": "orig",
#         "value": 0.4651608391608391,
#         "variable": "precision"
#       },
#       {
#         "k": 14,
#         "setting": "orig",
#         "value": 0.4574415584415585,
#         "variable": "precision"
#       },
#       {
#         "k": 15,
#         "setting": "orig",
#         "value": 0.4512,
#         "variable": "precision"
#       },
#       {
#         "k": 16,
#         "setting": "orig",
#         "value": 0.44475,
#         "variable": "precision"
#       },
#       {
#         "k": 17,
#         "setting": "orig",
#         "value": 0.4387700534759358,
#         "variable": "precision"
#       },
#       {
#         "k": 18,
#         "setting": "orig",
#         "value": 0.43204040404040406,
#         "variable": "precision"
#       },
#       {
#         "k": 19,
#         "setting": "orig",
#         "value": 0.42631578947368415,
#         "variable": "precision"
#       },
#       {
#         "k": 20,
#         "setting": "orig",
#         "value": 0.4200181818181818,
#         "variable": "precision"
#       },
#       {
#         "k": 21,
#         "setting": "orig",
#         "value": 0.4147012987012987,
#         "variable": "precision"
#       },
#       {
#         "k": 22,
#         "setting": "orig",
#         "value": 0.40886776859504137,
#         "variable": "precision"
#       },
#       {
#         "k": 23,
#         "setting": "orig",
#         "value": 0.4035177865612648,
#         "variable": "precision"
#       },
#       {
#         "k": 24,
#         "setting": "orig",
#         "value": 0.3985,
#         "variable": "precision"
#       },
#       {
#         "k": 25,
#         "setting": "orig",
#         "value": 0.3936581818181818,
#         "variable": "precision"
#       },
#       {
#         "k": 26,
#         "setting": "orig",
#         "value": 0.38883916083916087,
#         "variable": "precision"
#       },
#       {
#         "k": 27,
#         "setting": "orig",
#         "value": 0.38419528619528615,
#         "variable": "precision"
#       },
#       {
#         "k": 28,
#         "setting": "orig",
#         "value": 0.3797857142857143,
#         "variable": "precision"
#       },
#       {
#         "k": 29,
#         "setting": "orig",
#         "value": 0.37506583072100314,
#         "variable": "precision"
#       },
#       {
#         "k": 30,
#         "setting": "orig",
#         "value": 0.3708,
#         "variable": "precision"
#       },
#       {
#         "k": 31,
#         "setting": "orig",
#         "value": 0.36684457478005866,
#         "variable": "precision"
#       },
#       {
#         "k": 32,
#         "setting": "orig",
#         "value": 0.3628465909090909,
#         "variable": "precision"
#       },
#       {
#         "k": 33,
#         "setting": "orig",
#         "value": 0.3591460055096419,
#         "variable": "precision"
#       },
#       {
#         "k": 34,
#         "setting": "orig",
#         "value": 0.3557379679144385,
#         "variable": "precision"
#       },
#       {
#         "k": 35,
#         "setting": "orig",
#         "value": 0.3523168831168831,
#         "variable": "precision"
#       },
#       {
#         "k": 36,
#         "setting": "orig",
#         "value": 0.3488636363636364,
#         "variable": "precision"
#       },
#       {
#         "k": 37,
#         "setting": "orig",
#         "value": 0.34573464373464374,
#         "variable": "precision"
#       },
#       {
#         "k": 38,
#         "setting": "orig",
#         "value": 0.3424736842105263,
#         "variable": "precision"
#       },
#       {
#         "k": 39,
#         "setting": "orig",
#         "value": 0.3394032634032634,
#         "variable": "precision"
#       },
#       {
#         "k": 1,
#         "setting": "orig",
#         "value": 0.020557575757575757,
#         "variable": "recall"
#       },
#       {
#         "k": 2,
#         "setting": "orig",
#         "value": 0.03933333333333334,
#         "variable": "recall"
#       },
#       {
#         "k": 3,
#         "setting": "orig",
#         "value": 0.057139393939393934,
#         "variable": "recall"
#       },
#       {
#         "k": 4,
#         "setting": "orig",
#         "value": 0.07415757575757576,
#         "variable": "recall"
#       },
#       {
#         "k": 5,
#         "setting": "orig",
#         "value": 0.09016969696969697,
#         "variable": "recall"
#       },
#       {
#         "k": 6,
#         "setting": "orig",
#         "value": 0.10574545454545455,
#         "variable": "recall"
#       },
#       {
#         "k": 7,
#         "setting": "orig",
#         "value": 0.12086060606060606,
#         "variable": "recall"
#       },
#       {
#         "k": 8,
#         "setting": "orig",
#         "value": 0.1352848484848485,
#         "variable": "recall"
#       },
#       {
#         "k": 9,
#         "setting": "orig",
#         "value": 0.1492181818181818,
#         "variable": "recall"
#       },
#       {
#         "k": 10,
#         "setting": "orig",
#         "value": 0.16307878787878788,
#         "variable": "recall"
#       },
#       {
#         "k": 11,
#         "setting": "orig",
#         "value": 0.17632727272727272,
#         "variable": "recall"
#       },
#       {
#         "k": 12,
#         "setting": "orig",
#         "value": 0.18895757575757577,
#         "variable": "recall"
#       },
#       {
#         "k": 13,
#         "setting": "orig",
#         "value": 0.20156969696969698,
#         "variable": "recall"
#       },
#       {
#         "k": 14,
#         "setting": "orig",
#         "value": 0.21347272727272726,
#         "variable": "recall"
#       },
#       {
#         "k": 15,
#         "setting": "orig",
#         "value": 0.2256,
#         "variable": "recall"
#       },
#       {
#         "k": 16,
#         "setting": "orig",
#         "value": 0.2372,
#         "variable": "recall"
#       },
#       {
#         "k": 17,
#         "setting": "orig",
#         "value": 0.24863636363636363,
#         "variable": "recall"
#       },
#       {
#         "k": 18,
#         "setting": "orig",
#         "value": 0.2592242424242424,
#         "variable": "recall"
#       },
#       {
#         "k": 19,
#         "setting": "orig",
#         "value": 0.27,
#         "variable": "recall"
#       },
#       {
#         "k": 20,
#         "setting": "orig",
#         "value": 0.2800121212121212,
#         "variable": "recall"
#       },
#       {
#         "k": 21,
#         "setting": "orig",
#         "value": 0.2902909090909091,
#         "variable": "recall"
#       },
#       {
#         "k": 22,
#         "setting": "orig",
#         "value": 0.2998363636363636,
#         "variable": "recall"
#       },
#       {
#         "k": 23,
#         "setting": "orig",
#         "value": 0.30936363636363634,
#         "variable": "recall"
#       },
#       {
#         "k": 24,
#         "setting": "orig",
#         "value": 0.31880000000000003,
#         "variable": "recall"
#       },
#       {
#         "k": 25,
#         "setting": "orig",
#         "value": 0.32804848484848487,
#         "variable": "recall"
#       },
#       {
#         "k": 26,
#         "setting": "orig",
#         "value": 0.3369939393939394,
#         "variable": "recall"
#       },
#       {
#         "k": 27,
#         "setting": "orig",
#         "value": 0.34577575757575757,
#         "variable": "recall"
#       },
#       {
#         "k": 28,
#         "setting": "orig",
#         "value": 0.35446666666666665,
#         "variable": "recall"
#       },
#       {
#         "k": 29,
#         "setting": "orig",
#         "value": 0.36256363636363637,
#         "variable": "recall"
#       },
#       {
#         "k": 30,
#         "setting": "orig",
#         "value": 0.3708,
#         "variable": "recall"
#       },
#       {
#         "k": 31,
#         "setting": "orig",
#         "value": 0.3790727272727273,
#         "variable": "recall"
#       },
#       {
#         "k": 32,
#         "setting": "orig",
#         "value": 0.3870363636363636,
#         "variable": "recall"
#       },
#       {
#         "k": 33,
#         "setting": "orig",
#         "value": 0.3950606060606061,
#         "variable": "recall"
#       },
#       {
#         "k": 34,
#         "setting": "orig",
#         "value": 0.40316969696969696,
#         "variable": "recall"
#       },
#       {
#         "k": 35,
#         "setting": "orig",
#         "value": 0.4110363636363636,
#         "variable": "recall"
#       },
#       {
#         "k": 36,
#         "setting": "orig",
#         "value": 0.41863636363636364,
#         "variable": "recall"
#       },
#       {
#         "k": 37,
#         "setting": "orig",
#         "value": 0.42640606060606057,
#         "variable": "recall"
#       },
#       {
#         "k": 38,
#         "setting": "orig",
#         "value": 0.4338,
#         "variable": "recall"
#       },
#       {
#         "k": 39,
#         "setting": "orig",
#         "value": 0.44122424242424246,
#         "variable": "recall"
#       }
#     ]
#   },
#   "layer": [
#     {
#       "data": {
#         "name": "data-dadf82f9e97c86c9e017e3d22ff7dcf6"
#       },
#       "encoding": {
#         "color": {
#           "field": "variable",
#           "type": "nominal"
#         },
#         "x": {
#           "field": "k",
#           "type": "quantitative"
#         },
#         "y": {
#           "field": "value",
#           "type": "quantitative"
#         }
#       },
#       "height": 250,
#       "mark": {
#         "strokeDash": [
#           5,
#           3
#         ],
#         "type": "line"
#       },
#       "selection": {
#         "selector029": {
#           "bind": "scales",
#           "encodings": [
#             "x",
#             "y"
#           ],
#           "type": "interval"
#         }
#       },
#       "width": 600
#     },
#     {
#       "data": {
#         "name": "data-b4b51f601ddf0705ff19eae62b3a4007"
#       },
#       "encoding": {
#         "color": {
#           "field": "variable",
#           "type": "nominal"
#         },
#         "x": {
#           "field": "k",
#           "type": "quantitative"
#         },
#         "y": {
#           "field": "value",
#           "type": "quantitative"
#         }
#       },
#       "height": 250,
#       "mark": "line",
#       "selection": {
#         "selector030": {
#           "bind": "scales",
#           "encodings": [
#             "x",
#             "y"
#           ],
#           "type": "interval"
#         }
#       },
#       "width": 600
#     }
#   ]
# }
